# %% [markdown]
# <a href="https://colab.research.google.com/github/melmondro/Week4Warmup/blob/main/Copy_of_Week_1_Homework.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Week 1 Homework
#
# (Be sure to save this to Drive before starting)
#
# For this week we are going to practice requesting information from an API and manipulating it as JSON and as a Dataframe.
#
# We are going to keep working with Collection Builder. Head over to the [Collection Builder Example Projects](https://collectionbuilder.github.io/cb-examples/browse.html) listing and find a site that interests you. Spend some time browsing the website to get acquainted with its contents before proceeding with the questions.

# %%
#The Libraries we will need
import requests
import json
import pandas as pd
from random import randrange

# %%
# @markdown **H1** Find the URL of for the  _metadata.json_ of your selected site and paste it in here.
json_cb_url = "https://ilewis13.github.io/Mineral-and-Rock-Collection/assets/data/metadata.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_url)
#all of the data from the sites
total_cb_data = response_cb.json()
#just the 'objects' indexed in the site
objects_cb_data = total_cb_data['objects']
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# **H2** Run the 'show random cell' a few times to get a sense of what kind of data is in your chosen site.

# %%
#Run this a few times to see random entries in the JSON data that you retrieved.
random_entry = randrange(len(objects_cb_data))
print(json.dumps(objects_cb_data[random_entry],indent=2))
# Out:
# {
#   "title": "Leopard Skin Jasper",
#   "date": "2020-02",
#   "description": "A four inch piece of leopard skin jasper.",
#   "subject": "Minerals",
#   "location": "Mexico",
#   "latitude": "19.69467414",
#   "longitude": "-99.25981763",
#   "source": "Travis Jackson's Mineral and Rock Collection",
#   "type": "Image;StillImage",
#   "format": "image/jpeg",
#   "rights": "Public domain",
#   "rightsstatement": "http://rightsstatements.org/vocab/NoC-US/1.0/",
#   "reference_url": "https://ilewis13.github.io/Mineral-and-Rock-Collection/item.html?id=coll018"
# }

# %% [markdown]
# ## Different Fields!
#
# You can create any number of datafields and correpsonding values for those fields with a Collection Builder site. So the results from the output from the cell above will probably have wildly different results from [my site](https://elibtronic.github.io/AIL_Database/data.html) that we worked on in the Workalong notebook.
#
#
# You can see all of these options from grabbing the _facets.json_ URL from a collection builder homepage. Find that URL for your selected site for **H3**

# %%
# @markdown **H3** Find the URL of the facets.json for your selected site and paste it in here.
json_cb_facets_url = "https://ilewis13.github.io/Mineral-and-Rock-Collection/assets/data/facets.json" # @param {"type":"string","placeholder":""}

response_cb = requests.get(json_cb_facets_url)
#all of the data from the sites
total_facet_data = response_cb.json()
#just the 'objects' indexed in the site
print("Data fetched and JSON constructed!")
# Out:
# Data fetched and JSON constructed!

# %% [markdown]
# Run the cell below to see what the facets used for this site:

# %%
print(json.dumps(total_facet_data,indent=2))
# Out:
# {
#   "facets": [
#     {
#       "field": "subject",
#       "terms": {
#         "minerals": 20,
#         "rock": 4
#       }
#     },
#     {
#       "field": "creator",
#       "terms": {}
#     },
#     {
#       "field": "format",
#       "terms": {
#         "image/jpeg": 22
#       }
#     }
#   ]
# }

# %% [markdown]
# **H3** Try to read the JSON that is displayed to the screen. What possible facets are there in the the data. Fill them in the markdown list in the cell below. Add as many entries as you need to describe the site

# %% [markdown]
# Facets in my site are:
# - subject
# - creator
# - format

# %% [markdown]
# **H4** Which facet shows up the most for your selected site? Put your answer in the cell below

# %% [markdown]
# This facet that shows up the most is subject it is used 24 times on my selected site.

# %% [markdown]
# **H5** Turn the site _metadata.json_ data into a dataframe by completing the cell below. Part of it is written for you. You just need to modify line 4.

# %%
#H5

cb_data = pd.read_json(json_cb_url)
cb_normalized = pd.json_normalize(cb_data['objects'])
cb_normalized
# Out:
#                   title     date  \
Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 20  Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 21  Travis Jackson's Mineral and Rock Collection  Image;StillImage
#
#         format         rights                                rightsstatement  \
# 0   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 1   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 2   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 3   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 4   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 5   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 6   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 7   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 8   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 9   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 10  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 11  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 12  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 13  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 14  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 15  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 16  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 17  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 18  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 19  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 20  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 21  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
#
#                                         reference_url
# 0   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 1   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 2   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 3   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 4   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 5   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 6   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 7   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 8   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 9   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 10  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 11  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 12  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 13  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 14  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 15  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 16  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 17  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 18  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 19  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 20  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 21  https://ilewis13.github.io/Mineral-and-Rock-Co...

# %%
#Run this a few times to see random entries in your dataframe
cb_normalized.sample(10)
# Out:
#                   title     date  \
# 19            Aragonite  2021-01
# 8          Lapis Lazuli  2018-04
# 4             Malachite  2017-06
# 21            Amazonite  2021-02
# 13             Obsidian  2019-07
# 15          Tiger's Eye  2019-09
# 17  Leopard Skin Jasper  2020-02
# 11              Larimar  2018-10
# 3          Hemimorphite  2017-04
# 18           Aquamarine  2020-06
#
#                                           description         subject  \
# 19       A four inch piece of crystallized aragonite.        Minerals
# 8   Two forms of lapis lazuli: rough (L) and polis...  Minerals; Rock
# 4             An eleven inch polished malachite form.        Minerals
# 21  A rough (L) and polished (R) forms of amazonit...        Minerals
# 13  Two round specimens of volcanic glass also kno...            Rock
# 15  Two specimens of tiger's eye in its polished (...        Minerals
# 17          A four inch piece of leopard skin jasper.        Minerals
# 11                         One inch piece of larimar.        Minerals
# 3             A six inch piece of rough hemimorphite.        Minerals
# 18  A two inch polished piece of an aquamarine cry...        Minerals
#
#                             location      latitude     longitude  \
# 19                            Mexico   19.69467414  -99.25981763
# 8                        Afghanistan   35.01184718   69.20846466
# 4   Democratic Republic of the Congo  -4.552782962   16.36941636
# 21                            Brazil  -15.84344799  -46.69777208
# 13                       Nevada, USA   39.22465709  -119.9054761
# 15                      South Africa  -32.97912903   17.93479025
# 17                            Mexico   19.69467414  -99.25981763
# 11                Dominican Republic   18.60930085  -69.92760645
# 3                              China   41.46652845   116.0062578
# 18                            Brazil  -15.84344799  -46.69777208
#
#                                           source              type  \
# 19  Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 8   Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 4   Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 21  Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 13  Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 15  Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 17  Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 11  Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 3   Travis Jackson's Mineral and Rock Collection  Image;StillImage
# 18  Travis Jackson's Mineral and Rock Collection  Image;StillImage
#
#         format         rights                                rightsstatement  \
# 19  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 8   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 4   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 21  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 13  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 15  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 17  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 11  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 3   image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
# 18  image/jpeg  Public domain  http://rightsstatements.org/vocab/NoC-US/1.0/
#
#                                         reference_url
# 19  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 8   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 4   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 21  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 13  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 15  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 17  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 11  https://ilewis13.github.io/Mineral-and-Rock-Co...
# 3   https://ilewis13.github.io/Mineral-and-Rock-Co...
# 18  https://ilewis13.github.io/Mineral-and-Rock-Co...

# %% [markdown]
# **H6** This is for bonus!
# Try to write a pandas statement that will display your answer from **H4**. There are plenty of ways to do this, so feel free to use your imagination. What I have started for you here might not work, so feel free to change it as needed.

# %% [markdown]
# cb_normalized[cb_normalized["subject"] == "subject"].count()

# %%
subject_counts = cb_normalized['subject'].value_counts()

# %% [markdown]
# ## All Done!
#
# Congrats you are finished with this week's work. First save as PDF so that you can upload to the Course site then click the `Share` button above and enter `libraryjuicepresspython@gmail.com` so I can get a shared copy of your work.
